# %%
from textblob import TextBlob
import pandas as pd

# %%
df = pd.read_csv('~/Downloads/tweets.csv')

# %%
df.shape
# Out:
# (83135, 34)

# %%
s
# Out:
#                      coordinates                      created_at  \
# 0      -121.61901211,39.10080133  Thu Jul 23 05:55:49 +0000 2020
# 1               36.8167,-1.28333  Thu Jul 23 05:05:07 +0000 2020
# 2        12.04278973,48.51226938  Thu Jul 23 05:35:45 +0000 2020
# 3        15.27400541,37.82470642  Thu Jul 23 05:40:31 +0000 2020
# 4                            NaN  Thu Jul 23 06:21:47 +0000 2020
# ...                          ...                             ...
# 83130    36.81594609,-1.27887556  Wed Jul 15 04:15:42 +0000 2020
# 83131           -95.3694,29.7602  Wed Jul 15 03:32:08 +0000 2020
# 83132    120.98600758,14.5703617  Wed Jul 15 04:13:07 +0000 2020
# 83133          -73.98353,40.6783  Wed Jul 15 03:19:21 +0000 2020
# 83134           -93.0921,31.7543  Wed Jul 15 03:19:42 +0000 2020
#
#                                                 hashtags media  \
# 0                                       bestlife fitlife   NaN
# ...
